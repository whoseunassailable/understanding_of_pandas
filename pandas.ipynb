# %% [markdown]
# ### Understanding of Pandas

# %% [markdown]
# #### Loading the library

# %%
import pandas as pd

# %% [markdown]
# #### Loading the data frame

# %%
pookie = pd.read_csv('pokemon_data.csv') # Reading it in csv format
# pookie_in_excel_format = pd.read_excel('pokemon_data.xlsx') # Reading it in excel format
# pookie_in_txt_format = pd.read_csv('pokemon_data.txt', delimiter='\t') # Reading it in txt format
pookie
# pookie_in_excel_format
# pookie_in_txt_format
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# #### Reading the head of the Data

# %%
pookie.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %% [markdown]
# #### Reading the tail of the Data

# %%
pookie.tail(10)
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 790  714               Noibat   Flying  Dragon   40      30       35       45
# 791  715              Noivern   Flying  Dragon   85      70       80       97
# 792  716              Xerneas    Fairy     NaN  126     131       95      131
# 793  717              Yveltal     Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 790       40     55           6      False
# ...

# %% [markdown]
# #### Getting all the columns

# %%
pookie.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# #### Accessing a particular column

# %%
print(pookie['Name'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# #### Accessing first 5 rows of that column

# %%
pookie['Legendary'][69:420] # Accessing first five names of the Name column
# Out:
# 69     False
# 70     False
# 71     False
# 72     False
# 73     False
#        ...
# 415     True
# 416     True
# 417     True
# 418     True
# 419     True
# Name: Legendary, Length: 351, dtype: bool

# %% [markdown]
# #### Accessing n number of columns

# %%
print(pookie[['Name','Type 1','Type 2', 'Legendary']])
# Out:
#                       Name   Type 1  Type 2  Legendary
# 0                Bulbasaur    Grass  Poison      False
# 1                  Ivysaur    Grass  Poison      False
# 2                 Venusaur    Grass  Poison      False
# 3    VenusaurMega Venusaur    Grass  Poison      False
# 4               Charmander     Fire     NaN      False
# ..                     ...      ...     ...        ...
# 795                Diancie     Rock   Fairy       True
# 796    DiancieMega Diancie     Rock   Fairy       True
# 797    HoopaHoopa Confined  Psychic   Ghost       True
# 798     HoopaHoopa Unbound  Psychic    Dark       True
# 799              Volcanion     Fire   Water       True
#
# [800 rows x 4 columns]

# %% [markdown]
# #### Reading rows from a certain index to a certain index

# %%
pookie.iloc[69:420] # from index 69 to 419
# Out:
#        #                   Name    Type 1   Type 2  HP  Attack  Defense  \
# 69    64                Kadabra   Psychic      NaN  40      35       30
# 70    65               Alakazam   Psychic      NaN  55      50       45
# 71    65  AlakazamMega Alakazam   Psychic      NaN  55      50       65
# 72    66                 Machop  Fighting      NaN  70      80       50
# 73    67                Machoke  Fighting      NaN  80     100       70
# ..   ...                    ...       ...      ...  ..     ...      ...
# 415  378                 Regice       Ice      NaN  80      50      100
# 416  379              Registeel     Steel      NaN  80      75      150
# 417  380                 Latias    Dragon  Psychic  80      80       90
# 418  380      LatiasMega Latias    Dragon  Psychic  80     100      120
# 419  381                 Latios    Dragon  Psychic  80      90       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pookie.iloc[69, 11]
# Out:
# False

# %% [markdown]
# #### Iterating throught index and rows

# %%
for index, rows in pookie.iterrows():
    print(index, rows)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# ...

# %% [markdown]
# #### Loc can be use to look up for a particular value of a property in the data

# %%
pookie.loc[pookie['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %% [markdown]
# #### Describing Data

# %%
pookie.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# #### Sorting Data

# %%
pookie.sort_values('Name')  # By default it's ascending
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pookie.sort_values('Name', ascending=False) # When set to false will show the name values in descending order
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# #### n variables for sorting them in ascending or descending

# %%
pookie.sort_values(['Name', 'HP'], ascending= False) # A bit confused for this actually. The second parameter doesn't seems in descending order so
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# #### n variables sorting in both ascending and descending at the same time

# %%
pookie.sort_values(['Name', 'Attack'], ascending = [0, 1]) # 0 represents in ascending, 1 represents in descending
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# #### Creating a new column based on the data of other columns

# %%
pookie['total'] = pookie['Sp. Atk'] + pookie['Speed'] + pookie['Attack'] + pookie['Defense'] + pookie['Sp. Def']

pookie # From now on when you print pookie, you will see a new column name total that has a total of all the above stats
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  total
# 0         65       65     45           1      False    273
# ...

# %% [markdown]
# #### Remove the newly added column

# %%
pookie.drop(columns=['total']) # In case it is not dropping then redefine the dataframe. pookie = pookie.drop(columns=['total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# #### Using iloc in a different manner specifying rows and columns

# %%
pookie['total'] = pookie.iloc[:, 4:10].sum(axis=1) # :, specifies all rows and then axis=1 → Sum horizontally (row-wise sum)
pookie
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  total
# 0         65       65     45           1      False    318
# ...

# %% [markdown]
# #### Re-positioning the newly added column to the 4th index

# %%
cols = list(pookie.columns)
pookie = pookie[cols[0:4] + [cols[-1]] + cols[4:12]]

pookie
# Out:
#        #                   Name   Type 1  Type 2  total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# #### Saving the dataframe

# %%
# Saving in csv format
pookie.to_csv("modified_pokemon_data.csv", index= False) # Keeping index = False will remove the index column from the newly saved dataframe

# Saving in excel format
pookie.to_excel("modified_pokemon_data.xlsx", index= False)

# Saving in txt format
pookie.to_csv("modified_pokemon_data.txt", sep = "\t") # Like delimiter during reading txt file we have separator so we pass in the sep property in order to display the columns in the txt properly

# %% [markdown]
# #### Filtering the Data based on one condition

# %%
# Using loc to see a particular value
legendary_pokemon = pookie.loc[(pookie["Legendary"] == True)]
legendary_pokemon
# Out:
#        #                 Name    Type 1    Type 2  total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# ...

# %% [markdown]
# #### Filtering the Data based on multiple conditions

# %%
# Please use circular brackets and mention a condition inside it like (pookie["Legendary"] == True)
legendary_pokemon_with_highest_total = legendary_pokemon.loc[(legendary_pokemon["Legendary"] == True) & (legendary_pokemon['total'] > 650)]
legendary_pokemon_with_highest_total
# Out:
#        #                   Name   Type 1    Type 2  total   HP  Attack  \
# 162  150                 Mewtwo  Psychic       NaN    680  106     110
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 269  249                  Lugia  Psychic    Flying    680  106      90
# 270  250                  Ho-oh     Fire    Flying    680  106     130
# 418  380      LatiasMega Latias   Dragon   Psychic    700   80     100
# 420  381      LatiosMega Latios   Dragon   Psychic    700   80     130
# 421  382                 Kyogre    Water       NaN    670  100     100
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 423  383                Groudon   Ground       NaN    670  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# 425  384               Rayquaza   Dragon    Flying    680  105     150
# ...

# %% [markdown]
# #### Using sort on top of Filtering

# %%
sorted_legendary_pokemon = legendary_pokemon_with_highest_total.sort_values('total', ascending= True)
sorted_legendary_pokemon
# Out:
#        #                   Name   Type 1    Type 2  total   HP  Attack  \
# 710  646                 Kyurem   Dragon       Ice    660  125     130
# 421  382                 Kyogre    Water       NaN    670  100     100
# 423  383                Groudon   Ground       NaN    670  100     150
# 543  486              Regigigas   Normal       NaN    670  110     160
# 162  150                 Mewtwo  Psychic       NaN    680  106     110
# 793  717                Yveltal     Dark    Flying    680  126     131
# 792  716                Xerneas    Fairy       NaN    680  126     131
# 707  644                 Zekrom   Dragon  Electric    680  100     150
# 706  643               Reshiram   Dragon      Fire    680  100     120
# 545  487   GiratinaOrigin Forme    Ghost    Dragon    680  150     120
# 544  487  GiratinaAltered Forme    Ghost    Dragon    680  150     100
# 541  484                 Palkia    Water    Dragon    680   90     120
# ...

# %%
count_of_sorted_legendary_pokemon = sorted_legendary_pokemon.count().iloc[0]
count_of_sorted_legendary_pokemon
# Out:
# 28

# %% [markdown]
# #### Let's save the legendary pokemon with highest total over 650
# #### But while we do it, we need to make sure the indexing of the
# #### new data should not be equal to the old one

# %%
# reset_index(drop = True) will reset the index to 0 and remove the old index column
# Setting inplace = True will help you to not to set a new variable to new df and then save it
legendary_pokemon_with_highest_total.reset_index(drop=True, inplace=True)
legendary_pokemon_with_highest_total.to_csv("legendary_pokemon_with_highest_values.csv")

# %% [markdown]
# # Filtering Data with the contains()

# %%
pookie.loc[pookie['Name'].str.contains("Mega")] # Will display names with Mega in it
# Out:
#        #                       Name    Type 1    Type 2  total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# ...

# %% [markdown]
# #### Using regex with contains()

# %%
# You can do use the regular expression with the contains()
pookie.loc[pookie['Type 1'].str.contains("Fire|Grass",regex=True)]
# Out:
#        #                   Name Type 1  Type 2  total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# #### Setting the flag re.I = True to remove case sensitivity

# %%
import re # importing the required re library

# If you search for fire|grass you will get null because it is case sensitive
pookie.loc[pookie['Type 1'].str.contains("fire|grass",flags=re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2  total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# #### Using complex regex expression

# %%
# Names that start with go
pookie.loc[pookie['Name'].str.contains("^go[a-z]*",flags=re.I, regex=True)]
# Out:
#        #                   Name   Type 1  Type 2  total   HP  Attack  Defense  \
# 47    42                 Golbat   Poison  Flying    455   75      80       70
# 60    55                Golduck    Water     NaN    500   80      82       78
# 82    76                  Golem     Rock  Ground    495   80     120      130
# 127  118                Goldeen    Water     NaN    320   45      67       60
# 403  368               Gorebyss    Water     NaN    485   55      84      105
# 635  574                Gothita  Psychic     NaN    290   45      30       50
# 636  575              Gothorita  Psychic     NaN    390   60      45       70
# 637  576             Gothitelle  Psychic     NaN    490   70      55       95
# 683  622                 Golett   Ground   Ghost    303   59      74       50
# 684  623                 Golurk   Ground   Ghost    483   89     124       80
# 741  673                 Gogoat    Grass     NaN    531  123     100       62
# ...

# %% [markdown]
# #### Conditional changes

# %%
# So we are setting the Type 1 which are Fire as Flamer
pookie.loc[pookie['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
pookie
# Out:
#        #                   Name   Type 1  Type 2  total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander   Flamer     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion   Flamer   Water    600  80     110      120
#
# ...

# %%
# We are setting Fire Type as Legendary
pookie.loc[pookie['Type 1'] == 'Flamer', 'Legendary'] = True
pookie.loc[pookie['Type 1'] == 'Flamer'].head() # Displaying whether they are set to True or not
# Out:
#    #                       Name  Type 1  Type 2  total  HP  Attack  Defense  \
# 4  4                 Charmander  Flamer     NaN    309  39      52       43
# 5  5                 Charmeleon  Flamer     NaN    405  58      64       58
# 6  6                  Charizard  Flamer  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X  Flamer  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y  Flamer  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4       60       50     65           1       True
# 5       80       65     80           1       True
# 6      109       85    100           1       True
# 7      130       85    100           1       True
# 8      159      115    100           1       True

# %% [markdown]
# #### Setting multiple columns with single certain value conditional changes
# #### Setting Generation and Name to Next Level

# %%
pookie.loc[pookie['Legendary'] == True, ['Generation', 'Name']] = 'Next Level'
pookie
# Out:
# /var/folders/dw/fn12lc3x2b317ydc5b70v2340000gn/T/ipykernel_21223/2592923548.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Next Level' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   pookie.loc[pookie['Legendary'] == True, ['Generation', 'Name']] = 'Next Level'
#        #                   Name   Type 1  Type 2  total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Next Level   Flamer     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# ...

# %% [markdown]
# #### Setting multiple columns with multiple conditional values

# %%
# Setting Generation = 6 and Name = Ultra
pookie.loc[pookie['total'] > 650, ['Generation', 'Name']] = [6, 'Ultra'] 
pookie.loc[pookie['total'] > 650]
# Out:
#        #   Name   Type 1    Type 2  total   HP  Attack  Defense  Sp. Atk  \
# 162  150  Ultra  Psychic       NaN    680  106     110       90      154
# 163  150  Ultra  Psychic  Fighting    780  106     190      100      154
# 164  150  Ultra  Psychic       NaN    780  106     150       70      194
# 268  248  Ultra     Rock      Dark    700  100     164      150       95
# 269  249  Ultra  Psychic    Flying    680  106      90      130       90
# 270  250  Ultra   Flamer    Flying    680  106     130       90      110
# 313  289  Ultra   Normal       NaN    670  150     160      100       95
# 409  373  Ultra   Dragon    Flying    700   95     145      130      120
# 413  376  Ultra    Steel   Psychic    700   80     145      150      105
# 418  380  Ultra   Dragon   Psychic    700   80     100      120      140
# 420  381  Ultra   Dragon   Psychic    700   80     130      100      160
# 421  382  Ultra    Water       NaN    670  100     100       90      150
# ...

# %% [markdown]
# #### Aggregate Statistics

# %%
pookie = pd.read_csv('pokemon_data.csv') # Switching back to old data checkpoint
numeric_cols = pookie.select_dtypes(include=['number']).columns  # Select numeric columns
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# ...

# %% [markdown]
# #### Getting mean of Type 1 column

# %%
 pookie.groupby(['Type 1'])[numeric_cols].mean()
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# ...

# %% [markdown]
# #### Getting sum of Type 1 column

# %%
pookie.groupby(['Type 1'])[numeric_cols].sum()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# Type 1
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Dark      14302  2071    2740     2177     2314     2155   2361         125
# Dragon    15180  2666    3588     2764     3099     2843   2657         124
# Electric  15994  2631    3040     2917     3961     3243   3718         144
# Fairy      7642  1260    1046     1117     1335     1440    826          70
# Fighting   9824  1886    2613     1780     1434     1747   1784          91
# Fire      17025  3635    4408     3524     4627     3755   3871         167
# Flying     2711   283     315      265      377      290    410          22
# Ghost     15568  2062    2361     2598     2539     2447   2059         134
# Grass     24141  4709    5125     4956     5425     4930   4335         235
# Ground    11401  2361    3064     2715     1807     2008   2045         101
# ...

# %% [markdown]
# #### Getting count of Type 1 column

# %%
# pookie.groupby(['Type 1'])[numeric_cols].count()
pookie['count'] = 1 # adding a column name column and then giving all of them the value of 1 
pookie.groupby(['Type 1', 'Type 2'])[numeric_cols].count()
# Out:
#                   #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# Type 1 Type 2
# Bug    Electric   2   2       2        2        2        2      2           2
#        Fighting   2   2       2        2        2        2      2           2
#        Fire       2   2       2        2        2        2      2           2
#        Flying    14  14      14       14       14       14     14          14
#        Ghost      1   1       1        1        1        1      1           1
# ...              ..  ..     ...      ...      ...      ...    ...         ...
# Water  Ice        3   3       3        3        3        3      3           3
#        Poison     3   3       3        3        3        3      3           3
#        Psychic    5   5       5        5        5        5      5           5
#        Rock       4   4       4        4        4        4      4           4
#        Steel      1   1       1        1        1        1      1           1
#
# ...

# %% [markdown]
# #### sort_values() on top of aggregated group by

# %%
pookie.groupby(['Type 1'])[numeric_cols].mean().sort_values(['Defense', 'Attack'],ascending=[False, True])
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# ...

# %% [markdown]
# #### Reading chunks of data

# %%
for pookie in pd.read_csv('pokemon_data.csv', chunksize=5):
    print(pookie)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# ...

# %% [markdown]
# #### adding data to new dataframe

# %%
new_pookie = pd.DataFrame(columns=pookie.columns)
pookie
for pookie in pd.read_csv('pokemon_data.csv', chunksize=5):
    results = pookie.groupby('Type 1')[numeric_cols].count()
    new_pookie = pd.concat([new_pookie, results])
new_pookie
# Out:
#          # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire     1  NaN    NaN    NaN  1      1       1       1       1     1
# Grass    4  NaN    NaN    NaN  4      4       4       4       4     4
# Fire     4  NaN    NaN    NaN  4      4       4       4       4     4
# Water    1  NaN    NaN    NaN  1      1       1       1       1     1
# Bug      2  NaN    NaN    NaN  2      2       2       2       2     2
# ...     ..  ...    ...    ... ..    ...     ...     ...     ...   ...
# Fairy    1  NaN    NaN    NaN  1      1       1       1       1     1
# Flying   2  NaN    NaN    NaN  2      2       2       2       2     2
# Fire     1  NaN    NaN    NaN  1      1       1       1       1     1
# Psychic  2  NaN    NaN    NaN  2      2       2       2       2     2
# Rock     2  NaN    NaN    NaN  2      2       2       2       2     2
#
#         Generation Legendary
# Fire             1       NaN
# Grass            4       NaN
# Fire             4       NaN
# ...

# %% [markdown]
# # Completed
